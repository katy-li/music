# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
from sklearn import tree
import pandas as pd

# %%
df = pd.read_csv('complete.csv')
df.head()
# Out:
#              Song_artist  Song_duration_weeks  Song_isNew  Song_last_week  \
# 0          Ariana Grande                    6       False               1
# 1                 Halsey                   10       False               3
# 2           Travis Scott                   19       False               2
# 3  Marshmello & Bastille                   17       False               4
# 4    Panic! At The Disco                   19       False               5
#
#    Song_peak  Song_rank     Song_title  acousticness  categoryId  \
# 0          1          1  Thank U, Next       0.28000        10.0
# 1          2          2     Without Me       0.29700        10.0
# 2          1          3     Sicko Mode       0.00513        10.0
# 3          3          4        Happier       0.19100        10.0
# 4          5          5     High Hopes       0.19300        10.0
#
#                   channelId     ...      popularity  release_date  \
# 0  UC0VOyT2OCBKdQhF3BAbZ-1g     ...           100.0       11/3/18
# 1  UCm3FgJ2Hqm7tb70T-GfwXVA     ...            96.0       10/4/18
# 2  UClRx3MMyYUyqOxyEqA5F2nQ     ...            95.0        8/3/18
# 3  UCEdvpU2pFRCVqU6yIPyTpMQ     ...            95.0       8/17/18
# 4  UColJTBTSGqaaZr5NOk5r3Pg     ...            92.0       6/22/18
#
#    speechiness    tempo  time_signature  \
# 0       0.0658  106.960             4.0
# 1       0.0705  136.041             4.0
# 2       0.2220  155.008             4.0
# 3       0.0452  100.015             4.0
# 4       0.0618   82.014             4.0
#
#                                                title                track_id  \
# 0                      Ariana Grande - thank u, next  2rPE9A1vEgShuZxxzR2tZH
# 1                                Halsey - Without Me  5p7ujcrUXASCNwRaWNHR1C
# 2                Travis Scott - SICKO MODE ft. Drake  2xLMifQCjDGFmkHkpNLD9h
# 3  Marshmello ft. Bastille - Happier (Official Mu...  2dpaYNEQHiRxtZbfNsse99
# 4  Panic! At The Disco - High Hopes (Official Video)  1rqqCSm0Qe4I9rUvWncaom
#
#    valence      videoId    viewCount
# 0    0.435  gl1aHhXnN1k  231732139.0
# 1    0.533  ZAfAud_M_mg   61464289.0
# 2    0.446  6ONRf7h3Mdk  169182559.0
# 3    0.671  m7Bc3pLyij0  127921439.0
# 4    0.681  IPXIgEAGe4U  109787227.0
#
# [5 rows x 38 columns]

# %%
df.dropna(inplace=True)
df.head()
# Out:
#            Song_artist  Song_duration_weeks  Song_isNew  Song_last_week  \
# 0        Ariana Grande                    6       False               1
# 1               Halsey                   10       False               3
# 2         Travis Scott                   19       False               2
# 4  Panic! At The Disco                   19       False               5
# 5         Mariah Carey                   28       False               7
#
#    Song_peak  Song_rank                       Song_title  acousticness  \
# 0          1          1                    Thank U, Next       0.28000
# 1          2          2                       Without Me       0.29700
# 2          1          3                       Sicko Mode       0.00513
# 4          5          5                       High Hopes       0.19300
# 5          6          6  All I Want For Christmas Is You       0.16400
#
#    categoryId                 channelId     ...      popularity  release_date  \
# 0        10.0  UC0VOyT2OCBKdQhF3BAbZ-1g     ...           100.0       11/3/18
# 1        10.0  UCm3FgJ2Hqm7tb70T-GfwXVA     ...            96.0       10/4/18
# 2        10.0  UClRx3MMyYUyqOxyEqA5F2nQ     ...            95.0        8/3/18
# 4        10.0  UColJTBTSGqaaZr5NOk5r3Pg     ...            92.0       6/22/18
# 5        10.0  UClS0wn3LPs9jdX_yt2g1k8w     ...            95.0          1994
#
#    speechiness    tempo  time_signature  \
# 0       0.0658  106.960             4.0
# 1       0.0705  136.041             4.0
# 2       0.2220  155.008             4.0
# 4       0.0618   82.014             4.0
# 5       0.0386  150.277             4.0
#
#                                                title                track_id  \
# 0                      Ariana Grande - thank u, next  2rPE9A1vEgShuZxxzR2tZH
# 1                                Halsey - Without Me  5p7ujcrUXASCNwRaWNHR1C
# 2                Travis Scott - SICKO MODE ft. Drake  2xLMifQCjDGFmkHkpNLD9h
# 4  Panic! At The Disco - High Hopes (Official Video)  1rqqCSm0Qe4I9rUvWncaom
# 5     Mariah Carey - All I Want For Christmas Is You  0bYg9bo50gSsH3LtXe2SQn
#
#    valence      videoId    viewCount
# 0    0.435  gl1aHhXnN1k  231732139.0
# 1    0.533  ZAfAud_M_mg   61464289.0
# 2    0.446  6ONRf7h3Mdk  169182559.0
# 4    0.681  IPXIgEAGe4U  109787227.0
# 5    0.346  yXQViqx6GMY  535714338.0
#
# [5 rows x 38 columns]

# %%
y=df['danceability']
x=df[['acousticness', 'energy','liveness','speechiness','valence']]

# %%
X, y = make_regression(n_features=5, n_informative=2,random_state=0, shuffle=False)

# %%
regr = RandomForestRegressor(max_depth=2, random_state=0,n_estimators=100)

# %%
regr.fit(X, y)
RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=2,
           max_features='auto', max_leaf_nodes=None,
           min_impurity_decrease=0.0, min_impurity_split=None,
           min_samples_leaf=1, min_samples_split=2,
           min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
           oob_score=False, random_state=0, verbose=0, warm_start=False)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=2,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#            oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
print(regr.feature_importances_)
# Out:
# [6.58952650e-02 9.33337916e-01 7.66818529e-04 0.00000000e+00
#  0.00000000e+00]

# %%
print(regr.predict([[0, 0, 0,0,0]]))
# Out:
# [13.47176102]
