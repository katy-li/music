# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from keras.utils import to_categorical
from sklearn.preprocessing import OneHotEncoder
# Out:
# Using TensorFlow backend.

# %%
data = pd.read_csv("result")
data.head()
# Out:
#    Unnamed: 0    artist_name          track_name                track_id  \
# 0           0  Ariana Grande       thank u, next  2rPE9A1vEgShuZxxzR2tZH
# 1           1   Los Unidades  E-Lo (feat. Jozzy)  3eydp9rHJAskzOevEBK267
# 2           2   Travis Scott          SICKO MODE  2xLMifQCjDGFmkHkpNLD9h
# 3           3      Sheck Wes            Mo Bamba  1xzBco0xcoJEDXktl7Jxrr
# 4           4         Halsey          Without Me  5p7ujcrUXASCNwRaWNHR1C
#
#    popularity                                          image_url album_type  \
# 0         100  https://i.scdn.co/image/77eb7c17cafe550337bbb4...     single
# 1          70  https://i.scdn.co/image/3374fbd6b9310e8134b188...     single
# 2          95  https://i.scdn.co/image/cdca7dc20c778ada42fb18...      album
# 3          93  https://i.scdn.co/image/0e3e187e3ae399c7aa68c6...      album
# 4          96  https://i.scdn.co/image/dd916d01780a9591c8a029...     single
#
#    market_count album_release_date  duration_ms    ...      time_signature  \
# 0            78         2018-11-03       207333    ...                   4
# 1            78         2018-11-27       214720    ...                   4
# 2            78         2018-08-03       312820    ...                   4
# 3            78         2018-10-05       183906    ...                   4
# 4            78         2018-10-04       201660    ...                   4
#
#    valence  artist_name.1        track_name.1  album_release_date.1  \
# 0    0.435  Ariana Grande       thank u, next            2018-11-03
# 1    0.530   Los Unidades  E-Lo (feat. Jozzy)            2018-11-27
# 2    0.446   Travis Scott          SICKO MODE            2018-08-03
# 3    0.261      Sheck Wes            Mo Bamba            2018-10-05
# 4    0.533         Halsey          Without Me            2018-10-04
#
#    fm_listeners  fm_playcount  days_released       top_tag  tag_count
# 0      155294.0     3167732.0           59.0           pop        5.0
# 1          24.0         290.0           35.0           NaN        0.0
# 2           0.0           0.0          151.0           rap        5.0
# 3       75677.0      612946.0           88.0       Hip-Hop        5.0
# 4       93524.0      908823.0           89.0  best of 2018        5.0
#
# [5 rows x 29 columns]

# %%
data['popularity'].unique().tolist()
# Out:
# [100,
#  70,
#  95,
#  93,
#  96,
#  91,
#  89,
#  92,
#  88,
#  97,
#  86,
#  87,
#  85,
#  90,
#  83,
#  84,
#  82,
#  80,
#  94,
#  76,
#  81,
#  79,
#  78,
#  75,
#  73,
#  72,
#  74,
#  51,
#  69,
#  68,
#  77,
#  32,
#  71,
#  65,
#  61,
#  46,
#  39,
#  38,
#  36,
#  35,
#  34,
#  33,
#  30,
#  58,
#  54,
#  50,
#  49,
#  48,
#  47,
#  64,
#  67,
#  63,
#  66,
#  62,
#  60,
#  56,
#  59,
#  41,
#  40,
#  37,
#  25,
#  52,
#  57,
#  53,
#  31,
#  45,
#  23,
#  42,
#  2,
#  55,
#  0,
#  1,
#  5,
#  22,
#  44,
#  43,
#  8,
#  15,
#  29,
#  27,
#  21,
#  28,
#  24,
#  20,
#  19,
#  18,
#  17,
#  16,
#  14,
#  13,
#  12,
#  11,
#  10,
#  9]
